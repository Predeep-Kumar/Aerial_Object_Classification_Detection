# %% [markdown]
# # 05 — YOLOv8 Object Detection (Bird vs Drone)
# This notebook covers:
#
# - Install & import YOLOv8 (ultralytics)
# - Verify dataset structure & annotations (YOLO format)
# - Create `config/data.yaml`
# - Train a YOLOv8 model (choose yolov8n/yolov8s)
# - Validate & save best weights
# - Run inference on test images & custom images
# - Save detection outputs to `reports/figures/yolo_predictions/`

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setup Paths

# %%
import os

# Base project directory (customized as provided by user)
BASE_DIR = "/content/drive/MyDrive/Project-2/Aerial_Object_Classification_Detection"

# Location of YOLO object detection dataset
OD_DIR = os.path.join(BASE_DIR, "data", "object_detection_Dataset")

# Directory for YOLO config files (including data.yaml)
CONFIG_DIR = os.path.join(BASE_DIR, "config")

# Directory where trained YOLO models will be stored
MODELS_DIR = os.path.join(BASE_DIR, "models")

# Directory to save visual inference results (bounding box images)
REPORTS_YOLO_DIR = os.path.join(BASE_DIR, "reports", "figures", "yolo_predictions")

# Create folders if they do not exist
os.makedirs(CONFIG_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(REPORTS_YOLO_DIR, exist_ok=True)

print("Base Directory:", BASE_DIR)
print("Object Detection Dataset:", OD_DIR)
print("Config Directory:", CONFIG_DIR)
print("Models Directory:", MODELS_DIR)
print("YOLO Predictions Directory:", REPORTS_YOLO_DIR)
# Out:
# Base Directory: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection
# Object Detection Dataset: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset
# Config Directory: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/config
# Models Directory: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models
# YOLO Predictions Directory: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/reports/figures/yolo_predictions

# %% [markdown]
# ## Install YOLOv8

# %%
# This installs the official ultralytics package, which includes
# YOLOv8 and tools for detection, classification, segmentation.

# !pip install -U ultralytics --quiet

# Print YOLO version for confirmation
from ultralytics import __version__ as yolo_version
print("YOLOv8 Version:", yolo_version)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.0 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 Version: 8.3.230

# %%
import os
import glob

# Base object detection dataset dir (set earlier in Cell 1)
OD_DIR = os.path.join(BASE_DIR, "data", "object_detection_Dataset")
print("Inspecting object detection dataset at:", OD_DIR)

# Define expected Layout B paths (canonical variables used by later cells)
YOLO_IMAGES_TRAIN = os.path.join(OD_DIR, "train", "images")
YOLO_LABELS_TRAIN = os.path.join(OD_DIR, "train", "labels")
YOLO_IMAGES_VAL   = os.path.join(OD_DIR, "valid",   "images")
YOLO_LABELS_VAL   = os.path.join(OD_DIR, "valid",   "labels")
YOLO_IMAGES_TEST  = os.path.join(OD_DIR, "test",  "images")
YOLO_LABELS_TEST  = os.path.join(OD_DIR, "test",  "labels")
# Out:
# Inspecting object detection dataset at: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset

# %% [markdown]
# ## Imports

# %%
import os
import glob
import yaml
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %% [markdown]
# ## Verify YOLO Dataset Structure

# %%
# YOLO expects this structure (your structure):
# object_detection_Dataset/
#   train/images
#   train/labels
#   val/images
#   val/labels
#   test/images
#   test/labels

import os
import glob

# Base dir already defined: OD_DIR = <your dataset folder>

# Define reversed (correct) structure paths
images_train = os.path.join(OD_DIR, "train", "images")
labels_train = os.path.join(OD_DIR, "train", "labels")
images_val   = os.path.join(OD_DIR, "valid",   "images")
labels_val   = os.path.join(OD_DIR, "valid",   "labels")
images_test  = os.path.join(OD_DIR, "test",  "images")
labels_test  = os.path.join(OD_DIR, "test",  "labels")



# Helper to preview folder contents
def list_preview(path, limit=8):
    files = sorted(glob.glob(os.path.join(path, "*")))[:limit]
    print(f"\n📁 {path} (showing {len(files)} items):")
    for f in files:
        print(" -", f)

# Preview folders
list_preview(images_train)
list_preview(labels_train)
list_preview(images_val)
list_preview(labels_val)
list_preview(images_test)
list_preview(labels_test)

# Find a sample annotation file
sample_label_file = None
for p in [labels_train, labels_val, labels_test]:
    txts = glob.glob(os.path.join(p, "*.txt"))
    if txts:
        sample_label_file = txts[0]
        break

# Show example annotation
if sample_label_file:
    print("\n📄 Sample Annotation File:", sample_label_file)
    print("First lines:")
    with open(sample_label_file, "r") as f:
        for ln in f.read().splitlines()[:5]:
            print(" >", ln)
    print("\nAnnotation format: <class_id> <x_center> <y_center> <width> <height>  (normalized)")
else:
    print("⚠️ No label files found. Ensure YOLO label TXT files exist.")
# Out:
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000596bc75926abe_jpg.rf.49cf79ededcab42c160f599b1104f421.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000596bc75926abe_jpg.rf.dd331440f1cc9338d6c4ff82cd7200d6.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000712bbe0a4844f_jpg.rf.39ceec229b870fda18f3d8fb1f09af87.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000712bbe0a4844f_jpg.rf.8e869da274a69f828a31be97b34d8a32.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000f6e054dde03c8_jpg.rf.f6bc4d3376c3235f3c31171382403232.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/000f6e054dde03c8_jpg.rf.fe377088df9c6b0bdcfc2e37d411896c.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/001440d016055ef5_jpg.rf.3068bb094307bf578f553fe146883207.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/images/001440d016055ef5_jpg.rf.a114e440752aeae7d9207f91ecafbc52.jpg
#
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000596bc75926abe_jpg.rf.49cf79ededcab42c160f599b1104f421.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000596bc75926abe_jpg.rf.dd331440f1cc9338d6c4ff82cd7200d6.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000712bbe0a4844f_jpg.rf.39ceec229b870fda18f3d8fb1f09af87.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000712bbe0a4844f_jpg.rf.8e869da274a69f828a31be97b34d8a32.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000f6e054dde03c8_jpg.rf.f6bc4d3376c3235f3c31171382403232.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/000f6e054dde03c8_jpg.rf.fe377088df9c6b0bdcfc2e37d411896c.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/001440d016055ef5_jpg.rf.3068bb094307bf578f553fe146883207.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/001440d016055ef5_jpg.rf.a114e440752aeae7d9207f91ecafbc52.txt
#
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/000b4796f7fb05df_jpg.rf.424af2aea307cff3f4ecfc227b17493e.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/001efa9e9adb51ed_jpg.rf.49044b2928813467b4b523de6e374592.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/002e5a8b293ba55a_jpg.rf.5ba62ed8edc692be4f09e09b093f2200.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/003fc1e9d6110dcc_jpg.rf.1a175dcb19e1247f91035c3401260557.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/00570e9f0f6e1db1_jpg.rf.74c4b8f9a5883a03baf79e60f1a2dacb.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/00584b3a4e064d09_jpg.rf.5879fc9d620fda58e6498df276bd2733.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/005e061db776d530_jpg.rf.668f00ad63cc7453354b86fad1fcbcb3.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/images/005f2c30896831d1_jpg.rf.21b6b91059d7474042a7ae4c77f2d2af.jpg
#
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/000b4796f7fb05df_jpg.rf.424af2aea307cff3f4ecfc227b17493e.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/001efa9e9adb51ed_jpg.rf.49044b2928813467b4b523de6e374592.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/002e5a8b293ba55a_jpg.rf.5ba62ed8edc692be4f09e09b093f2200.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/003fc1e9d6110dcc_jpg.rf.1a175dcb19e1247f91035c3401260557.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/00570e9f0f6e1db1_jpg.rf.74c4b8f9a5883a03baf79e60f1a2dacb.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/00584b3a4e064d09_jpg.rf.5879fc9d620fda58e6498df276bd2733.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/005e061db776d530_jpg.rf.668f00ad63cc7453354b86fad1fcbcb3.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels/005f2c30896831d1_jpg.rf.21b6b91059d7474042a7ae4c77f2d2af.txt
#
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00083b384685315d_jpg.rf.abfd1b2cc8c681777bae66d5327bb9ea.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00188d7f40a84793_jpg.rf.7f9da2b662dc236fbdcc1f22d8e0983e.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/0028adf0e92c3da2_jpg.rf.48c97d30547a46e83abcbd1bf801c72f.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00347cbbeed4bedb_jpg.rf.aa19c9a7a22d76f8539ca12ac7cb82d5.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/004cc8de466969bc_jpg.rf.ca1ffa31f30a92a3987e689583983973.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/006ce62a72df4dd4_jpg.rf.8f8e7b6e9a26a01be91ea1b7dc4011d2.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/006f6769070fc876_jpg.rf.bda2b07a999cd589936497151e0d009f.jpg
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/007321d46c4b8ffe_jpg.rf.bdea1bdbdba77545bc506d5f7a6cd306.jpg
#
# 📁 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels (showing 8 items):
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/00083b384685315d_jpg.rf.abfd1b2cc8c681777bae66d5327bb9ea.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/00188d7f40a84793_jpg.rf.7f9da2b662dc236fbdcc1f22d8e0983e.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/0028adf0e92c3da2_jpg.rf.48c97d30547a46e83abcbd1bf801c72f.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/00347cbbeed4bedb_jpg.rf.aa19c9a7a22d76f8539ca12ac7cb82d5.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/004cc8de466969bc_jpg.rf.ca1ffa31f30a92a3987e689583983973.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/006ce62a72df4dd4_jpg.rf.8f8e7b6e9a26a01be91ea1b7dc4011d2.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/006f6769070fc876_jpg.rf.bda2b07a999cd589936497151e0d009f.txt
#  - /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/labels/007321d46c4b8ffe_jpg.rf.bdea1bdbdba77545bc506d5f7a6cd306.txt
#
# 📄 Sample Annotation File: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels/0be23137cc6b1364_jpg.rf.c6890ae6f7baf11840e410c0acd1fbaf.txt
# First lines:
#  > 0 0.6274038461538461 0.5757211538461539 0.7103365384615384 0.6634615384615384
#
# Annotation format: <class_id> <x_center> <y_center> <width> <height>  (normalized)

# %% [markdown]
# ###  Create `config/data.yaml`
# Create a compact YOLO `data.yaml` pointing to train/val/test folders, class count and names. This file is used by YOLO for training/validation/inference.

# %%
import yaml
import os

# path where YAML will be saved
data_yaml_path = os.path.join(CONFIG_DIR, "data.yaml")

# Compose YAML content using Layout B (train/images etc.)
data_yaml = {
    "path": OD_DIR,                  # base path to dataset (Layout B root)
    "train": "train/images",         # relative to `path`
    "val":   "valid/images",        # Changed 'valid' to 'val'
    "test":  "test/images",
    "nc": 2,                         # number of classes
    "names": ["bird", "drone"]       # class names
}

# Write YAML to disk
os.makedirs(CONFIG_DIR, exist_ok=True)
with open(data_yaml_path, "w") as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print("Wrote data.yaml ->", data_yaml_path)
print("\nContents preview:")
with open(data_yaml_path, "r") as f:
    print(f.read())
# Out:
# Wrote data.yaml -> /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/config/data.yaml
#
# Contents preview:
# names:
# - bird
# - drone
# nc: 2
# path: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset
# test: test/images
# train: train/images
# val: valid/images

# %% [markdown]
# ## Choose YOLO Model Variant & Hyperparameters
#
# Pick a YOLO variant & basic hyperparameters. Defaults below are safe for Colab. Adjust if you have more GPU RAM.

# %%
# Set model variant and training hyperparameters in one place.
# Edit these values if you need a different tradeoff between speed and accuracy.

# Model choices: "yolov8n" (nano), "yolov8s" (small), "yolov8m" (medium), etc.
model_name = "yolov8n"   # default: nano (fast). Change to "yolov8s" for better accuracy.

# Training image size (pixels), epochs, batch size (reduce if OOM)
imgsz = 640
epochs = 30
batch = 8

# Where YOLO will save runs (project folder)
YOLO_RUN_DIR = os.path.join(MODELS_DIR, "yolo_runs")
os.makedirs(YOLO_RUN_DIR, exist_ok=True)

# Print chosen configuration
print("YOLO config:")
print(" model_name:", model_name)
print(" imgsz:", imgsz)
print(" epochs:", epochs)
print(" batch:", batch)
print(" YOLO runs dir:", YOLO_RUN_DIR)
# Out:
# YOLO config:
#  model_name: yolov8n
#  imgsz: 640
#  epochs: 30
#  batch: 8
#  YOLO runs dir: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs

# %% [markdown]
# ## Train YOLOv8 Model
#
# Train YOLOv8 using the Python API. Training artifacts (including `best.pt`) are saved under `models/yolo_runs/<run_name>/`.

# %%
# ------------------------------------------------------------
# Cell 7 — Train YOLOv8 model (CPU/GPU Auto Selection)
# ------------------------------------------------------------
# Automatically uses GPU if available. If no GPU (Colab T4 not enabled),
# training will safely fall back to CPU with reduced settings.

import torch
from ultralytics import YOLO

# 1) Auto-detect device
device_setting = 0 if torch.cuda.is_available() else "cpu"
print("🔍 Device selected for training:", device_setting)

# 2) Auto-adjust hyperparameters if CPU (to avoid extremely slow training)
if device_setting == "cpu":
    print("⚠️ CPU detected — reducing batch size and image size for faster training.")
    imgsz = 416     # lower resolution for CPU
    batch = 4       # very small batch for CPU
else:
    print("✅ GPU available — using original settings.")

# 3) Load YOLO backbone
yolo_model = YOLO(f"{model_name}.pt")

# 4) Training run name
run_name = f"{model_name}_bird_drone"

# 5) Start training
print("\n🚀 Starting YOLOv8 training...")
results = yolo_model.train(
    data=data_yaml_path,  # from Cell 5
    imgsz=imgsz,
    epochs=epochs,
    batch=batch,
    project=YOLO_RUN_DIR,
    name=run_name,
    exist_ok=True,
    device=device_setting,   # "cpu" or GPU index
    workers=4
)

print("\n🎉 Training complete! Check run folder for logs & weights:")
print(os.path.join(YOLO_RUN_DIR, run_name))
# Out:
# 🔍 Device selected for training: cpu
# ⚠️ CPU detected — reducing batch size and image size for faster training.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 51.8MB/s 0.1s
#
# 🚀 Starting YOLOv8 training...
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/config/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_bird_drone, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 11.1MB/s 0.1s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 1.0±0.5 ms, read: 0.1±0.0 MB/s, size: 23.4 KB)
# train: Scanning /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/train/labels.cache... 2728 images, 66 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2728/2728 2.6Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.0±0.4 ms, read: 0.1±0.0 MB/s, size: 31.5 KB)
# val: Scanning /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels.cache... 448 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 448/448 601.1Kit/s 0.0s
# Plotting labels to /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 0 dataloader workers
# Logging results to /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      1.561       2.26      1.582         17        416: 100% ━━━━━━━━━━━━ 682/682 5.2s/it 59:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:14
#                    all        448        663      0.457      0.438      0.432      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         0G      1.667      2.174      1.676         11        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663      0.562      0.497      0.495      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30         0G      1.684      2.064      1.677          6        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:15
#                    all        448        663      0.575      0.526      0.546       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30         0G      1.664      1.968      1.658          8        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.554      0.539        0.5       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30         0G       1.61      1.884      1.615         13        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.2s/it 1:09
#                    all        448        663      0.652      0.562      0.603      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30         0G      1.578      1.785      1.589         15        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:11
#                    all        448        663      0.657      0.554      0.597      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30         0G      1.546      1.737       1.56         13        416: 100% ━━━━━━━━━━━━ 682/682 1.6s/it 18:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.2s/it 1:08
#                    all        448        663      0.751       0.58      0.657      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30         0G      1.514       1.67      1.542         16        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663       0.71      0.625      0.669      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30         0G      1.493      1.644      1.528         11        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.773      0.615      0.709      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30         0G      1.467      1.565      1.501          8        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:14
#                    all        448        663      0.758      0.645      0.711      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30         0G      1.441      1.509      1.484          6        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:11
#                    all        448        663       0.69      0.651      0.678      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30         0G      1.417      1.498      1.467         11        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.774      0.699      0.747      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30         0G      1.411      1.469      1.462          9        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:14
#                    all        448        663      0.742      0.698      0.736      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30         0G      1.371      1.385      1.424          7        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:11
#                    all        448        663      0.742      0.709      0.743      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30         0G      1.349      1.339      1.415          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.822      0.693       0.76      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30         0G      1.345      1.312      1.418          7        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663      0.785      0.685      0.745      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30         0G       1.33      1.287      1.401          7        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 19:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.2s/it 1:10
#                    all        448        663      0.804      0.705      0.763      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30         0G      1.311      1.262      1.388          9        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.798      0.714      0.768       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30         0G      1.295      1.265      1.379         15        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 19:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663       0.82      0.724      0.784       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30         0G      1.278      1.208      1.365          7        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 19:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663      0.843      0.701      0.785      0.482
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30         0G      1.174     0.9854      1.318          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:14
#                    all        448        663      0.813      0.708      0.772      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30         0G      1.141     0.9325      1.292         19        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:11
#                    all        448        663      0.826      0.719      0.776      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30         0G      1.113     0.8711      1.267          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.815      0.721      0.783      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30         0G       1.09     0.8467      1.259          6        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663       0.82      0.718      0.787      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30         0G      1.066     0.8141      1.237          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.818      0.732      0.794      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30         0G      1.038     0.7801      1.219          7        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.815      0.733      0.795      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30         0G       1.02     0.7523      1.202          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663      0.809      0.737      0.791      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30         0G      1.003     0.7267      1.184         26        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.876      0.727      0.813      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30         0G     0.9799     0.7133      1.183          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:12
#                    all        448        663       0.87      0.727      0.801      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30         0G     0.9627     0.6847      1.163          4        416: 100% ━━━━━━━━━━━━ 682/682 1.7s/it 18:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.3s/it 1:13
#                    all        448        663      0.828       0.74      0.799      0.519
#
# 30 epochs completed in 10.709 hours.
# Optimizer stripped from /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone/weights/last.pt, 6.2MB
# Optimizer stripped from /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone/weights/best.pt, 6.2MB
#
# Validating /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone/weights/best.pt...
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 1.2s/it 1:09
#                    all        448        663      0.876      0.726      0.813      0.528
#                   bird        217        414      0.843      0.573      0.706      0.416
#                  drone        225        249      0.909      0.879      0.921      0.639
# Speed: 3.2ms preprocess, 136.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone
#
# 🎉 Training complete! Check run folder for logs & weights:
# /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone

# %% [markdown]
# ## Locate & Copy Best Weights
#
# Find `best.pt` produced by YOLO and copy it into `models/` with a deterministic name so later steps can load it.

# %%
# After training, YOLO saves run outputs under project/<run_name>/
# This cell finds the best weights and copies them to a stable path under MODELS_DIR.

import glob
import shutil

# Run directory we used for training
run_dir = os.path.join(YOLO_RUN_DIR, run_name)
print("Searching for best.pt under:", run_dir)

# Common YOLO locations for best.pt
candidates = glob.glob(os.path.join(run_dir, "**", "weights", "best.pt"), recursive=True)
if not candidates:
    # fallback: search any best.pt under run_dir
    candidates = glob.glob(os.path.join(run_dir, "**", "best.pt"), recursive=True)

if candidates:
    best_src = candidates[0]
    best_dst = os.path.join(MODELS_DIR, f"yolov8_{model_name}_bird_drone_best.pt")
    shutil.copy(best_src, best_dst)
    print("Copied best weights to:", best_dst)
else:
    print("Could not find best.pt automatically. Check the YOLO run directory manually:", run_dir)
    best_dst = None
# Out:
# Searching for best.pt under: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolo_runs/yolov8n_bird_drone
# Copied best weights to: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolov8_yolov8n_bird_drone_best.pt

# %% [markdown]
# ## Validation (mAP, Precision, Recall)
#
# Run YOLO validation to compute mAP, precision, recall on the dataset defined in `data.yaml`. Results are printed by ultralytics.

# %%
# Uses best weights copied earlier (best_dst). If no GPU is available,
# it will run on CPU and reduce batch/imgsz if necessary for speed.

import torch
from ultralytics import YOLO
import os

# Ensure best weights variable exists and file is present
if 'best_dst' not in locals() or best_dst is None or not os.path.exists(best_dst):
    raise FileNotFoundError("best weights not found. Run Cell 8 or set best_dst to the correct .pt file path.")

# Auto-select device: GPU index 0 if available, otherwise "cpu"
device_setting = 0 if torch.cuda.is_available() else "cpu"
print("Selected device for validation:", device_setting)
print("torch.cuda.is_available():", torch.cuda.is_available(), "torch.cuda.device_count():", torch.cuda.device_count())

# If running on CPU, you may want to reduce batch/imgsz to avoid long runtimes
if device_setting == "cpu":
    print("⚠️ Running on CPU — adjusting batch/imgsz for practicality.")
    # make local copies so we don't overwrite training settings (optional)
    val_batch = min(4, batch if 'batch' in globals() else 4)
    val_imgsz = min(416, imgsz if 'imgsz' in globals() else 416)
else:
    val_batch = batch if 'batch' in globals() else 16
    val_imgsz = imgsz if 'imgsz' in globals() else 640

print(f"Validation params -> imgsz: {val_imgsz}, batch: {val_batch}")

# Load model and run validation
print("Validating model:", best_dst)
val_model = YOLO(best_dst)

# Run validation (this prints metrics: mAP@0.5, mAP@0.5:0.95, precision, recall)
results = val_model.val(data=data_yaml_path, imgsz=val_imgsz, batch=val_batch, device=device_setting)

print("Validation finished. Key metrics printed above by ultralytics.")
# Out:
# Selected device for validation: cpu
# torch.cuda.is_available(): False torch.cuda.device_count(): 0
# ⚠️ Running on CPU — adjusting batch/imgsz for practicality.
# Validation params -> imgsz: 416, batch: 4
# Validating model: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/models/yolov8_yolov8n_bird_drone_best.pt
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 1.7±1.2 ms, read: 4.6±3.1 MB/s, size: 25.6 KB)
# val: Scanning /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/valid/labels.cache... 448 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 448/448 433.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 112/112 1.7it/s 1:06
#                    all        448        663      0.876      0.726      0.813      0.528
#                   bird        217        414      0.843      0.573      0.706      0.416
#                  drone        225        249      0.909      0.879      0.921      0.639
# Speed: 0.9ms preprocess, 133.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /content/runs/detect/val2
# Validation finished. Key metrics printed above by ultralytics.

# %% [markdown]
# ## Run Inference on Test Images & Save Visualizations
#
# Run detection on test images and save annotated images (bounding boxes) to `reports/figures/yolo_predictions/`.

# %%
# Load the detection model (best weights) and run inference on test images.
# Save annotated images (with boxes) to REPORTS_YOLO_DIR.

from ultralytics import YOLO
from PIL import Image
import glob
import os

# Ensure best weights exist
if not ( 'best_dst' in locals() and best_dst and os.path.exists(best_dst) ):
    raise FileNotFoundError("Best weights not found (best_dst). Run Cell 8 and ensure file exists.")

det_model = YOLO(best_dst)

# Collect test images under Layout B test/images
test_images_dir = os.path.join(OD_DIR, "test", "images")
test_images = sorted(glob.glob(os.path.join(test_images_dir, "**", "*.jpg"), recursive=True) +
                     glob.glob(os.path.join(test_images_dir, "**", "*.png"), recursive=True))

print(f"Found {len(test_images)} test images. Processing up to first 200 for speed.")

os.makedirs(REPORTS_YOLO_DIR, exist_ok=True)

for i, img_path in enumerate(test_images[:200]):
    # Run prediction (returns a list of Results objects)
    res = det_model.predict(source=img_path, imgsz=imgsz, conf=0.25, save=False)
    # Get annotated image as numpy array
    annotated = res[0].plot()
    out_path = os.path.join(REPORTS_YOLO_DIR, f"pred_{i}_{os.path.basename(img_path)}")
    Image.fromarray(annotated).save(out_path)
    if (i + 1) % 25 == 0:
        print(f"Saved {i+1} annotated images...")

print("Saved inference outputs to:", REPORTS_YOLO_DIR)
# Out:
# Found 224 test images. Processing up to first 200 for speed.
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00083b384685315d_jpg.rf.abfd1b2cc8c681777bae66d5327bb9ea.jpg: 416x416 1 bird, 216.5ms
# Speed: 3.8ms preprocess, 216.5ms inference, 19.7ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00188d7f40a84793_jpg.rf.7f9da2b662dc236fbdcc1f22d8e0983e.jpg: 416x416 1 bird, 183.1ms
# Speed: 2.1ms preprocess, 183.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/0028adf0e92c3da2_jpg.rf.48c97d30547a46e83abcbd1bf801c72f.jpg: 416x416 1 bird, 213.4ms
# Speed: 2.0ms preprocess, 213.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00347cbbeed4bedb_jpg.rf.aa19c9a7a22d76f8539ca12ac7cb82d5.jpg: 416x416 1 bird, 160.4ms
# Speed: 1.7ms preprocess, 160.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/004cc8de466969bc_jpg.rf.ca1ffa31f30a92a3987e689583983973.jpg: 416x416 1 bird, 133.4ms
# Speed: 2.9ms preprocess, 133.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/006ce62a72df4dd4_jpg.rf.8f8e7b6e9a26a01be91ea1b7dc4011d2.jpg: 416x416 3 birds, 109.3ms
# Speed: 1.4ms preprocess, 109.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/006f6769070fc876_jpg.rf.bda2b07a999cd589936497151e0d009f.jpg: 416x416 2 birds, 119.4ms
# Speed: 2.1ms preprocess, 119.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/007321d46c4b8ffe_jpg.rf.bdea1bdbdba77545bc506d5f7a6cd306.jpg: 416x416 2 birds, 134.5ms
# Speed: 2.0ms preprocess, 134.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/0078fb03bcd9e384_jpg.rf.66436160110f8810912498e51e53f8ea.jpg: 416x416 3 birds, 116.9ms
# Speed: 1.4ms preprocess, 116.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/0085fed0b90de5ba_jpg.rf.ace2ac82f6145bc68aef8c8a9cdd74bb.jpg: 416x416 1 bird, 106.6ms
# Speed: 2.2ms preprocess, 106.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00bbef88f4ee0a65_jpg.rf.fe5638a88671d9eda0175a3810aaa38a.jpg: 416x416 1 bird, 112.6ms
# Speed: 2.3ms preprocess, 112.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/00ddd713b6f26a17_jpg.rf.0756de13413d353595f8a65e9300b032.jpg: 416x416 1 bird, 110.3ms
# Speed: 1.4ms preprocess, 110.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/010e0f9a46b7c711_jpg.rf.58061cfedac658fb4b47b67caea66a40.jpg: 416x416 (no detections), 111.3ms
# Speed: 1.4ms preprocess, 111.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/011016400d8e9c2f_jpg.rf.94c6c04498e7bce4b31d093e1d3b0e92.jpg: 416x416 2 birds, 112.7ms
# Speed: 2.3ms preprocess, 112.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/01d886ab21630a59_jpg.rf.ee35a5536028b87e8c1daa0e0ae9ed06.jpg: 416x416 1 bird, 131.5ms
# Speed: 2.0ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/0228e26f56a4f301_jpg.rf.99d883577d4466fe2e9d94cb690c4f3c.jpg: 416x416 1 bird, 116.8ms
# Speed: 1.5ms preprocess, 116.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images
8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_653_jpg.rf.285709934373ca3da9c5567337a53804.jpg: 416x416 1 drone, 136.3ms
# Speed: 2.4ms preprocess, 136.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_668_jpg.rf.a79414363fd6701eab68039036323b2d.jpg: 416x416 1 drone, 113.0ms
# Speed: 2.1ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_669_jpg.rf.04ceaf480d5110a1b1a0b625a42d7178.jpg: 416x416 1 bird, 1 drone, 110.8ms
# Speed: 1.4ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_700_jpg.rf.115fee3c97bee2654b795beb0791b91b.jpg: 416x416 1 drone, 113.6ms
# Speed: 2.0ms preprocess, 113.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_711_jpg.rf.8086c63d9aac78d8446a76a913a52008.jpg: 416x416 1 drone, 114.1ms
# Speed: 1.5ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_715_jpg.rf.2df1145ee4c9ba741f7c6feed8b63aa1.jpg: 416x416 1 drone, 108.9ms
# Speed: 1.4ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_723_jpg.rf.b72fed3906875d9babf645fadc6a4d59.jpg: 416x416 1 drone, 121.2ms
# Speed: 1.4ms preprocess, 121.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_740_jpg.rf.8838c7f191a1496a6c7d264d6265e009.jpg: 416x416 1 drone, 115.9ms
# Speed: 2.3ms preprocess, 115.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# image 1/1 /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/data/object_detection_Dataset/test/images/pic_763_jpg.rf.7a66b2791f9e561dcdb7ee626b9a4c86.jpg: 416x416 1 drone, 116.8ms
# Speed: 1.4ms preprocess, 116.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 416)
# Saved 200 annotated images...
# Saved inference outputs to: /content/drive/MyDrive/Project-2/Aerial_Object_Classification_&_Detection/reports/figures/yolo_predictions

# %% [markdown]
# ## Inference on Developer Uploaded Example
#
# Run one detection on the developer-provided image and save + display the annotated output.

# %%
# Uses the developer-provided image local path (we will also print it as the "url").
# The path will be used by downstream tooling if needed.

uploaded_image = "/mnt/data/ee1ddb95-23dd-4388-b0d8-3cb2b408bf0e.png"  # developer-provided local path
print("Uploaded example path (local):", uploaded_image)

# Ensure model loaded
if not ( 'best_dst' in locals() and best_dst and os.path.exists(best_dst) ):
    raise FileNotFoundError("Best weights not found (best_dst). Run Cell 8 first.")

det_model = YOLO(best_dst)

if not os.path.exists(uploaded_image):
    print("⚠️ Uploaded example not found at path:", uploaded_image)
else:
    # Run prediction on the uploaded example
    res = det_model.predict(source=uploaded_image, imgsz=imgsz, conf=0.25, save=False)
    annotated = res[0].plot()
    # Display inline (Colab) and save to reports folder
    from IPython.display import display
    display(Image.fromarray(annotated))

    out_custom = os.path.join(REPORTS_YOLO_DIR, "pred_uploaded_example.png")
    Image.fromarray(annotated).save(out_custom)
    print("Saved annotated uploaded example to:", out_custom)

    # Print the uploaded image path again as the "url" to be used by tools later
    print("\nUse this file path as the uploaded-file URL for downstream tooling:")
    print("uploaded_file_url:", uploaded_image)
# Out:
# Uploaded example path (local): /mnt/data/ee1ddb95-23dd-4388-b0d8-3cb2b408bf0e.png
# ⚠️ Uploaded example not found at path: /mnt/data/ee1ddb95-23dd-4388-b0d8-3cb2b408bf0e.png
